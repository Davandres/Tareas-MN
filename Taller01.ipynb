# %%
# y(x)=x^3-7x^2+4x+12
def eqn(x: int) -> int:
    # ** símbolo de potencia en python, no se usa el `^` como en otros lenguajes
    return x**3 - 1 * x**2 + 14 * x + 1

# %%
# generación de puntos para la gráfica
import numpy as np

## TAREA generar 100 datos del -10 al 10
Xs, step = np.linspace(-6, 20, num=58, retstep=True)

# %%
Ys = []
for x in Xs:
    y = eqn(x)
    # Xs.append(x)
    Ys.append(y)
    print(f"x = {x:.2f} \ty = {y:.2e}")
Ys
# Out:
# x = -6.00 	y = -3.35e+02
# x = -5.54 	y = -2.78e+02
# x = -5.09 	y = -2.28e+02
# x = -4.63 	y = -1.85e+02
# x = -4.18 	y = -1.48e+02
# x = -3.72 	y = -1.16e+02
# x = -3.26 	y = -9.01e+01
# x = -2.81 	y = -6.83e+01
# x = -2.35 	y = -5.04e+01
# x = -1.89 	y = -3.59e+01
# x = -1.44 	y = -2.42e+01
# x = -0.98 	y = -1.47e+01
# x = -0.53 	y = -6.79e+00
# x = -0.07 	y = 1.23e-02
# x = 0.39 	y = 6.31e+00
# x = 0.84 	y = 1.27e+01
# x = 1.30 	y = 1.97e+01
# x = 1.75 	y = 2.79e+01
# x = 2.21 	y = 3.79e+01
# x = 2.67 	y = 5.02e+01
# x = 3.12 	y = 6.54e+01
# x = 3.58 	y = 8.41e+01
# x = 4.04 	y = 1.07e+02
# x = 4.49 	y = 1.34e+02
# x = 4.95 	y = 1.67e+02
# x = 5.40 	y = 2.05e+02
# x = 5.86 	y = 2.50e+02
# x = 6.32 	y = 3.01e+02
# x = 6.77 	y = 3.61e+02
# x = 7.23 	y = 4.28e+02
# x = 7.68 	y = 5.03e+02
# x = 8.14 	y = 5.88e+02
# x = 8.60 	y = 6.83e+02
# x = 9.05 	y = 7.88e+02
# x = 9.51 	y = 9.03e+02
# x = 9.96 	y = 1.03e+03
# x = 10.42 	y = 1.17e+03
# x = 10.88 	y = 1.32e+03
# x = 11.33 	y = 1.49e+03
# x = 11.79 	y = 1.67e+03
# x = 12.25 	y = 1.86e+03
# x = 12.70 	y = 2.07e+03
# x = 13.16 	y = 2.29e+03
# x = 13.61 	y = 2.53e+03
# x = 14.07 	y = 2.79e+03
# x = 14.53 	y = 3.06e+03
# x = 14.98 	y = 3.35e+03
# x = 15.44 	y = 3.66e+03
# x = 15.89 	y = 3.99e+03
# x = 16.35 	y = 4.33e+03
# x = 16.81 	y = 4.70e+03
# x = 17.26 	y = 5.09e+03
# x = 17.72 	y = 5.50e+03
# x = 18.18 	y = 5.93e+03
# x = 18.63 	y = 6.38e+03
# x = 19.09 	y = 6.86e+03
# x = 19.54 	y = 7.36e+03
# x = 20.00 	y = 7.88e+03
# [-335.0,
#  -277.73550296177507,
#  -227.8080003023872,
#  -184.6480536521359,
#  -147.6862246413201,
#  -116.35307490023922,
#  -90.07916605919232,
#  -68.29505974847862,
#  -50.43131759839736,
#  -35.91850123924772,
#  -24.187172301328886,
#  -14.667892414940097,
#  -6.791223210380534,
#  0.01227368205061441,
#  6.312036632054119,
#  12.677504009330805,
#  19.678114183581446,
#  27.88330552450685,
#  37.86251640180782,
#  50.185185185185176,
#  65.42075024433969,
#  84.1386499489721,
#  106.90832266878334,
#  134.29920677347414,
#  166.8807406327452,
#  205.22236261629752,
#  249.8935110938318,
#  301.46362443504887,
#  360.5021410096492,
#  427.57849918733416,
#  503.26213733780435,
#  588.12249383076,
#  682.729007035903,
#  787.6511153229333,
#  903.4582570615516,
#  1030.7198706214594,
#  1170.005394372357,
#  1321.884266683946,
#  1486.9259259259256,
#  1665.6998104679972,
#  1858.7753586798635,
#  2066.7220089312223,
#  2290.109199591776,
#  2529.5063690312268,
#  2785.4829556192717,
#  3058.6083977256144,
#  3349.4521337199567,
#  3658.5836019719954,
#  3986.572240851434,
#  4333.987488727976,
#  4701.3987839713145,
#  5089.3755649511595,
#  5498.487270037203,
#  5929.303337599151,
#  6382.393206006707,
#  6858.326313629564,
#  7357.672098837426,
#  7881.0]

# %%
from matplotlib import pyplot as plt

# import seaborn as sns ## alternativa chévere

plt.plot(Xs, Ys, marker=".", color="blue", linestyle=":")
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.title("Gráfica de función cúbica")
plt.grid()
plt.legend(["$y=x^3-7x^2+4x+12$"])
plt.show()

## TAREA hacer zoom
